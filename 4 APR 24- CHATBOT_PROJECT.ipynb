# %% [markdown]
# ### CHATBOT fot Travel Industry:
# ![image-2.png](attachment:image-2.png)

# %%
import nltk
from nltk.chat.util import Chat, reflections

#Pairs is a list of patterns and responses.

QnA= [
    [
        r"(.*)hello|hey|hi|hii|hola|hie(.*)",
        ["Hello! How can I assist you today?",]
    ],
    [
        r"(.*)help(.*)",
        ["Sure, I'm here to help. What do you need assistance with?",]
    ],
    [
        r"(.*)book a flight(.*)",
        ["Of course! To book a flight, please provide your travel dates, destination, and any other preferences you have.",]
    ],
    [
        r"(.*)recommend a hotel(.*)",
        ["Certainly! What city are you traveling to, and what type of accommodation are you looking for?"]
    ],
    [
        r"(.*)weather(.*)in (.*)",
        ["Let me check the weather forecast for %3. One moment please...", "In %3, the weather forecast is..."]
    ],
    [
        r"(.*)tourist attractions(.*)in (.*)",
        ["Some popular tourist attractions in %3 include..."]
    ],
    [
        r"(.*)travel restrictions(.*)",
        ["Before traveling, it's important to check for any travel restrictions or advisories. I can provide you with information on current restrictions if you'd like."]
    ],
    [
        r"(.*)thank you(.*)",
        ["You're welcome! If you have any more questions, feel free to ask."]
    ],
    [
        r"(.*)flight status(.*)",
        ["To check the status of your flight, please provide the airline, flight number, and departure date."]
    ],
    [
        r"(.*)car rental(.*)",
        ["We offer car rental services in various locations. What city are you looking to rent a car in?"]
    ],
    [
        r"(.*)cancellation policy(.*)",
        ["Our cancellation policy varies depending on the booking. Please provide your booking details, and I can assist you further."]
    ],
    [
        r"(.*)travel insurance(.*)",
        ["We offer travel insurance options for your trip. Would you like more information about our travel insurance packages?"]
    ],
    [
        r"(.*)currency exchange(.*)",
        ["We can assist you with currency exchange services. What currency are you looking to exchange?"]
    ],
    [
        r"(.*)local transportation(.*)",
        ["For local transportation options, you can use taxis, public buses, or ride-sharing services like Uber or Lyft."]
    ],
    [
        r"(.*)airport transfer(.*)",
        ["We provide airport transfer services to and from major airports. Please provide your flight details, and we can arrange transportation for you."]
    ],
    [
        r"(.*)visa requirements(.*)",
        ["Visa requirements vary depending on your destination and nationality. I can provide you with information on visa requirements for specific countries."]
    ],
    [
        r"(.*)travel advisory(.*)",
        ["It's important to check for any travel advisories or alerts before your trip. I can help you find information on current travel advisories."]
    ],
    [
        r"(.*)travel with pets(.*)",
        ["We can provide you with information on pet-friendly accommodations and airlines that allow pets onboard."]
    ],
    [
        r"(.*)group travel(.*)",
        ["We offer group travel packages for various destinations. How many people are in your group, and where would you like to travel?"]
    ],
    [
        r"(.*)destination wedding(.*)",
        ["We specialize in destination weddings and can help you plan your dream wedding in a beautiful location."]
    ],
    [
        r"(.*)honeymoon packages(.*)",
        ["We offer honeymoon packages to romantic destinations around the world. Where would you like to go for your honeymoon?"]
    ],
    [
        r"(.*)traveling solo(.*)",
        ["Traveling solo can be a wonderful experience! We can help you plan your solo adventure and provide tips for solo travelers."]
    ],
    [
        r"(.*)travel itinerary(.*)",
        ["We can assist you in creating a customized travel itinerary based on your interests and preferences."]
    ],
    [
        r"(.*)wifi availability(.*)",
        ["Many hotels and public places offer free wifi. We can help you find accommodations with wifi access during your trip."]
    ],
    [
        r"(.*)language translation(.*)",
        ["We can provide translation services or recommend translation apps to help you communicate in foreign languages."]
    ],
    [
        r"(.*)travel documents(.*)",
        ["It's important to have valid travel documents such as passports and visas. We can assist you with obtaining any necessary travel documents for your trip."]
    ],
    [
        r"(.*)travel packing tips(.*)",
        ["We can provide you with packing tips and a packing checklist to ensure you have everything you need for your trip."]
    ],
    [
        r"(.*)traveling with children(.*)",
        ["Traveling with children requires some extra planning. We can provide you with tips and recommendations for family-friendly destinations and activities."]
    ],
    [
        r"(.*)adventure travel(.*)",
        ["If you're looking for adventure, we can help you plan exciting outdoor activities such as hiking, trekking, and safari tours."]
    ],
    [
        r"(.*)cultural experiences(.*)",
        ["Immerse yourself in the local culture with our cultural experiences, including cooking classes, cultural tours, and traditional performances."]
    ],
    [
        r"(.*)budget travel(.*)",
        ["Traveling on a budget? We can help you find affordable accommodations, transportation options, and activities for your trip."]
    ],
    [
        r"(.*)business travel(.*)",
        ["We offer business travel services including corporate discounts, group bookings, and assistance with travel arrangements."]
    ],
    [
        r"(.*)travel rewards program(.*)",
        ["Join our travel rewards program to earn points on your bookings and enjoy exclusive benefits such as upgrades, discounts, and freebies."]
    ],
    [
        r"(.*)travel safety tips(.*)",
        ["Your safety is our top priority. We can provide you with travel safety tips and information on staying safe while traveling."]
    ],
    [
        r"(.*)sightseeing tours(.*)",
        ["Explore the sights and attractions of your destination with our sightseeing tours. We offer guided tours to popular landmarks and hidden gems."]
    ],
    [
        r"(.*)beach vacation(.*)",
        ["Relax and unwind on a beautiful beach vacation. We can help you find beachfront accommodations and plan fun activities like snorkeling, surfing, and sunset cruises."]
    ],
    [
        r"(.*)cruise vacation(.*)",
        ["Set sail on a luxurious cruise vacation. We offer cruise packages to stunning destinations with onboard amenities and exciting shore excursions."]
    ],
    [
        r"(.*)eco-friendly travel(.*)",
        ["Travel responsibly with our eco-friendly travel options. We can help you find sustainable accommodations, transportation, and activities for your trip."]
    ],
    [
        r"(.*)luxury travel(.*)",
        ["Indulge in luxury travel experiences with our exclusive packages. From luxury resorts to private tours, we can help you plan the ultimate luxury getaway."]
    ]
    ]
    
print("Hey traveller, I'm your travel assistant and I would like to chat with you \nPlease type lowercase English language to start a conversation. Type quit to leave ")
#Create Chat Bot
chat = Chat(QnA, reflections)


chat.converse()
# Out:
# Hey traveller, I'm your travel assistant and I would like to chat with you
# Please type lowercase English language to start a conversation. Type quit to leave
# >hi
# Hello! How can I assist you today?
# >Can u help to book a flight
# Sure, I'm here to help. What do you need assistance with?
# >i want to do adventure trave
# None
# >i want to do adventure travel
# If you're looking for adventure, we can help you plan exciting outdoor activities such as hiking, trekking, and safari tours.
# >need travel itinerary
# We can assist you in creating a customized travel itinerary based on your interests and preferences.
# >thank you
# You're welcome! If you have any more questions, feel free to ask.
